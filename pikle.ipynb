# %%
import pandas as pd
try:
    print("Membaca CSV...")
    df = pd.read_csv("data.csv") # Pastikan nama file CSV benar
    print("Menyimpan Pickle...")
    df.to_pickle("data.pkl")
    print("SUKSES! data.pkl baru berhasil dibuat.")
except Exception as e:
    print(f"ERROR: {e}")
# Out:
# Membaca CSV...
# Menyimpan Pickle...
# SUKSES! data.pkl baru berhasil dibuat.
